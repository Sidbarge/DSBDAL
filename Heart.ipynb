# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\siddh\Downloads\Heart.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
data.tail()
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No

# %%
data.shape
# Out:
# (303, 15)

# %%
data.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
data.columns #shows name of all columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
data.rename(columns={'Sex': 'Gender'}, inplace=True) #rename a column
data['Gender']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 298    1
# 299    1
# 300    1
# 301    0
# 302    1
# Name: Gender, Length: 303, dtype: int64

# %%
data.isnull().sum() #Total number of null values column-wise
# Out:
# Unnamed: 0    0
# Age           0
# Gender        0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
data.dtypes #datatype of each column
# Out:
# Unnamed: 0      int64
# Age             int64
# Gender          int64
# ChestPain      object
# RestBP          int64
# Chol            int64
# Fbs             int64
# RestECG         int64
# MaxHR           int64
# ExAng           int64
# Oldpeak       float64
# Slope           int64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
data['Age'].mean() #mean of data in that column
# Out:
# 54.43894389438944

# %%
data['Age'].min() #minimum value of data in that column
# Out:
# 29

# %%
data['Age'].max() #maximum value of data in that column
# Out:
# 77

# %%
#Cross_Validation
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, random_state=0, test_size=0.3) #data split into 70:30

# %%
train.shape #dimension of training set
# Out:
# (212, 15)

# %%
test.shape #dimension of testing set
# Out:
# (91, 15)

# %%
train
# Out:
#      Unnamed: 0  Age  Gender     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 137         138   62       1    nontypical     120   281    0        2    103
# 106         107   59       1  asymptomatic     140   177    0        0    162
# 284         285   61       1  asymptomatic     148   203    0        0    161
# 44           45   61       0  asymptomatic     130   330    0        2    169
# 139         140   51       1    nonanginal     125   245    1        2    166
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 251         252   58       1  asymptomatic     146   218    0        0    105
# 192         193   43       1  asymptomatic     132   247    1        2    143
# 117         118   35       0  asymptomatic     138   183    0        0    182
# 47           48   50       1  asymptomatic     150   243    0        2    128
# 172         173   59       0  asymptomatic     174   249    0        0    143
#
# ...

# %%
test
# Out:
#      Unnamed: 0  Age  Gender     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 225         226   34       0    nontypical     118   210    0        0    192
# 152         153   67       0    nonanginal     115   564    0        2    160
# 228         229   54       1  asymptomatic     110   206    0        2    108
# 201         202   64       0  asymptomatic     180   325    0        0    154
# 52           53   44       1  asymptomatic     112   290    0        2    153
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 253         254   51       0    nonanginal     120   295    0        2    157
# 293         294   63       1  asymptomatic     140   187    0        2    144
# 76           77   60       1  asymptomatic     125   258    0        2    141
# 272         273   46       1  asymptomatic     140   311    0        0    120
# 238         239   49       0    nontypical     134   271    0        0    162
#
# ...

# %%
count=data.Thal.unique().size

# %%
count
# Out:
# 4

# %%
data.Thal.unique()
# Out:
# array(['fixed', 'normal', 'reversable', nan], dtype=object)

# %%
from sklearn import preprocessing

# %%
labelEncoding=preprocessing.LabelEncoder()

# %%
data['AHD']=labelEncoding.fit_transform(data['AHD'])

# %%
data
# Out:
#      Unnamed: 0  Age  Gender     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63       1       typical     145   233    1        2    150
# 1             2   67       1  asymptomatic     160   286    0        2    108
# 2             3   67       1  asymptomatic     120   229    0        2    129
# 3             4   37       1    nonanginal     130   250    0        0    187
# 4             5   41       0    nontypical     130   204    0        2    172
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 298         299   45       1       typical     110   264    0        0    132
# 299         300   68       1  asymptomatic     144   193    1        0    141
# 300         301   57       1  asymptomatic     130   131    0        0    115
# 301         302   57       0    nontypical     130   236    0        2    174
# 302         303   38       1    nonanginal     138   175    0        0    173
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Gender        0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
data['Ca']=data['Ca'].fillna(data['Ca'].mean())
data['Thal']=data['Thal'].fillna(data['Thal'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Gender        0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          0
# AHD           0
# dtype: int64

# %%
data
# Out:
#      Unnamed: 0  Age  Gender     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63       1       typical     145   233    1        2    150
# 1             2   67       1  asymptomatic     160   286    0        2    108
# 2             3   67       1  asymptomatic     120   229    0        2    129
# 3             4   37       1    nonanginal     130   250    0        0    187
# 4             5   41       0    nontypical     130   204    0        2    172
# ..          ...  ...     ...           ...     ...   ...  ...      ...    ...
# 298         299   45       1       typical     110   264    0        0    132
# 299         300   68       1  asymptomatic     144   193    1        0    141
# 300         301   57       1  asymptomatic     130   131    0        0    115
# 301         302   57       0    nontypical     130   236    0        2    174
# 302         303   38       1    nonanginal     138   175    0        0    173
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=data[['RestBP']]
y=data[['MaxHR']]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
model=reg.fit(xtrain,ytrain)

# %%
ypredict=model.predict(xtest)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,9))
plt.scatter(xtrain,ytrain,color='Blue')
plt.plot(xtest,ypredict,color='Red')
plt.title('BP vs HR')
plt.xlabel('RestBP')
plt.ylabel('MaxHR')
plt.show()
